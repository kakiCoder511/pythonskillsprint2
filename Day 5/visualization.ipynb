# %%
import pandas as pd

# %%
df = pd.read_csv("housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import seaborn

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
g = sns.relplot(
    kind="scatter",
    data=df,
    x="longitude",
    y="latitude",
    hue="ocean_proximity"
)
g.set(title ="Geographical location of Areas in California")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x="tip", y="total_bill",data =tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x="tip", y="total_bill",data =tips, hue= "day")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x="tip", y="total_bill",data =tips, hue= "day", size = "size")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x="tip", y="total_bill",data =tips, hue= "day", size = "size", palette="YlGnBu")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
#Mini Challenge
#Try some other combinations of x and y axis for the tips dataset in a scatterplot, 
#and see if you can come up with 3 trends/types of correlation that you can clearly see in the data

# %%
sns.scatterplot(x="tip",y="sex", data = tips, hue ="day",size="size")
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
#man loves to go out on Sat and Sun
#woman loves to drink in a resturant

# %%
sns.scatterplot(x="tip",y="day", data = tips, hue ="smoker",size="size")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
#many smokers on Friday

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips["tip"],kde=True, bins=30)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#barplot
#useful when dealing with categorical data
sns.barplot(x="sex", y ="tip", data= tips, hue="sex", palette = "YlGnBu")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(data= tips, x="day", y = "tip", hue="sex", palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data= tips, x="day", y = "tip", hue="sex", palette="YlGnBu", dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data= tips, x="day", y = "tip", hue="sex", palette="YlGnBu")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
#join plot
sns.jointplot(x= "tip",y ="total_bill", data= tips, kind="reg")

# %%
#task - to explore both of the below plots using the seaboron
#pairplot
sns.pairplot(tips, x_vars=["total_bill"], y_vars=["tip"], kind="reg")

# %%
#heatmap
import matplotlib.pyplot as plt

corr = tips.corr(numeric_only=True)   # correlation matrix
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()
